# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/12/2018-2019/2018-2019-La-Liga-Stats"
data=requests.get(standings_url)
data.text
# Out:
# '    \n      \n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www/base" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202303231" />\n<!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://cmp.quantcast.com\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \n\t\t    \'/choice.js?tag_version=V2\');\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertBefore(element, firstScript);\n\t\n\tfunction makeStub() {\n\t    var TCF_LOCATOR_NAME = \'__tcfapiLocator\';\n\t    var queue = [];\n\t    var win = window;\n\t    var cmpFrame;\n\t    \n\t    function addFrame() {\n\t\tvar doc = win.document;\n\t\tvar otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);\n\t\t\n\t\tif (!otherCMP) {\n\t\t    if (doc.body) {\n\t\t\tvar iframe = doc.createElement(\'iframe\');\n\t\t\t\n\t\t\tiframe.style.cssText = \'display:none\';\n\t\t\tiframe.name = TCF_LOCATOR_NAME;\n\t\t\tdoc.body.appendChild(iframe);\n\t\t    } else {\n\t\t\tsetTimeout(addFrame, 5);\n\t\t    }\n\t\t}\n\t\treturn !otherCMP;\n\t    }\n\t    \n\t    function tcfAPIHandler() {\n\t\tvar gdprApplies;\n\t\tvar args = arguments;\n\t\t\n\t\tif (!args.length) {\n\t\t    return queue;\n\t\t} else if (args[0] === \'setGdprApplies\') {\n\t\t    if (\n\t\t\targs.length > 3 &&\n\t\t\t    args[2] === 2 &&\n\t\t\t    typeof args[3] === \'boolean\'\n\t\t    ) {\n\t\t\tgdprApplies = args[3];\n\t\t\tif (typeof args[2] === \'function\') {\n\t\t\t    args[2](\'set\', true);\n\t\t\t}\n\t\t    }\n\t\t} else if (args[0] === \'ping\') {\n\t\t    var retr = {\n\t\t\tgdprApplies: gdprApplies,\n\t\t\tcmpLoaded: false,\n\t\t\tcmpStatus: \'stub\'\n\t\t    };\n\t\t    \n\t\t    if (typeof args[2] === \'function\') {\n\t\t\targs[2](retr);\n\t\t    }\n\t\t} else {\n\t\t    if(args[0] === \'init\' && typeof args[3] === \'object\') {\n\t\t\targs[3] = Object.assign(args[3], { tag_version: \'V2\' });\n\t\t    }\n\t\t    queue.push(args);\n\t\t}\n\t    }\n\t    \n\t    function postMessageEventHandler(event) {\n\t\tvar msgIsString = typeof event.data === \'string\';\n\t\tvar json = {};\n\t\t\n\t\ttry {\n\t\t    if (msgIsString) {\n\t\t\tjson = JSON.parse(event.data);\n\t\t    } else {\n\t\t\tjson = event.data;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tvar payload = json.__tcfapiCall;\n\t\t\n\t\tif (payload) {\n\t\t    window.__tcfapi(\n\t\t\tpayload.command,\n\t\t\tpayload.version,\n\t\t\tfunction(retValue, success) {\n\t\t\t    var returnMsg = {\n\t\t\t\t__tcfapiReturn: {\n\t\t\t\t    returnValue: retValue,\n\t\t\t\t    success: success,\n\t\t\t\t    callId: payload.callId\n\t\t\t\t}\n\t\t\t    };\n\t\t\t    if (msgIsString) {\n\t\t\t\treturnMsg = JSON.stringify(returnMsg);\n\t\t\t    }\n\t\t\t    if (event && event.source && event.source.postMessage) {\n\t\t\t\tevent.source.postMessage(returnMsg, \'*\');\n\t\t\t    }\n\t\t\t},\n\t\t\tpayload.parameter\n\t\t    );\n\t\t}\n\t    }\n\t    \n\t    while (win) {\n\t\ttry {\n\t\t    if (win.frames[TCF_LOCATOR_NAME]) {\n\t\t\tcmpFrame = win;\n\t\t\tbreak;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tif (win === window.top) {\n\t\t    break;\n\t\t}\n\t\twin = win.parent;\n\t    }\n\t    if (!cmpFrame) {\n\t\taddFrame();\n\t\twin.__tcfapi = tcfAPIHandler;\n\t\twin.addEventListener(\'message\', postMessageEventHandler, false);\n\t    }\n\t};\n\t\n\tmakeStub();\n\t\n\tvar uspStubFunction = function() {\n\t    var arg = arguments;\n\t    if (typ ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
standings_table
# Out:
# <table class="stats_table sortable min_width force_mobilize" data-cols-to-freeze=",2" id="results2018-2019121_overall"> <caption>Regular season Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rank" class="poptip sort_default_asc center" data-stat="rank" data-tip="&lt;strong&gt;Rank&lt;/strong&gt;&lt;br&gt;Squad finish in competition&lt;br&gt;Finish within the league or competition.&lt;br&gt;For knockout competitions may show final round reached.&lt;br&gt;Colors and arrows represent promotion/relegation or qualifiation for continental cups.&lt;br&gt;Trophy indicates team won league whether by playoffs or by leading the table.&lt;br&gt;Star indicates topped table in league USING another means of naming champion." scope="col">Rk</th> <th aria-label="Squad" class="poptip sort_default_asc center" data-stat="team" scope="col">Squad</th> <th aria-label="Matches Played" class="poptip center" data-stat="games" data-tip="&lt;strong&gt;Matches Played&lt;/strong&gt;&lt;br&gt;Matches Played by the player or squad" scope="col">MP</th> <th aria-label="Wins" class="poptip center" data-stat="wins" data-tip="&lt;strong&gt;Wins&lt;/strong&gt;&lt;br&gt;Wins" scope="col">W</th> <th aria-label="Draws" class="poptip center" data-stat="ties" data-tip="&lt;strong&gt;Draws&lt;/strong&gt;&lt;br&gt;Draws" scope="col">D</th> <th aria-label="Losses" class="poptip center" data-stat="losses" data-tip="&lt;strong&gt;Losses&lt;/strong&gt;&lt;br&gt;Losses" scope="col">L</th> <th aria-label="Goals For" class="poptip center" data-stat="goals_for" data-tip="&lt;strong&gt;Goals For&lt;/strong&gt;&lt;br&gt;Goals For" scope="col">GF</th> <th aria-label="Goals Against" class="poptip center" data-stat="goals_against" data-tip="&lt;strong&gt;Goals Against&lt;/strong&gt;&lt;br&gt;Goals Against" scope="col">GA</th> <th aria-label="Goal Difference" class="poptip center" data-stat="goal_diff" data-tip="&lt;strong&gt;Goal Difference&lt;/strong&gt;&lt;br&gt;Goal Difference" scope="col">GD</th> <th aria-label="Points" class="poptip center" data-stat="points" data-tip="&lt;strong&gt;Points&lt;/strong&gt;&lt;br&gt;Most leagues are ordered by points.&lt;br&gt;Three for a win and one for a draw." scope="col">Pts</th> <th aria-label="Points/Game" class="poptip center" data-stat="points_avg" data-tip="&lt;strong&gt;Points/Game&lt;/strong&gt;&lt;br&gt;Points per Match Played" scope="col">Pts/MP</th> <th aria-label="xG" class="poptip center" data-filter="1" data-name="xG" data-stat="xg_for" data-tip="&lt;strong&gt;Expected Goals&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xG</th> <th aria-label="xG Allowed" class="poptip sort_default_asc center" data-stat="xg_against" data-tip="&lt;strong&gt;xG Allowed&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Expected Goals Allowed&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xGA</th> <th aria-label="xG Difference" class="poptip center" data-filter="1" data-name="xG Difference" data-stat="xg_diff" data-tip="&lt;strong&gt;xG Difference&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Expected Goals Difference&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xGD</th> <th aria-label="xG Difference/90" class="poptip hide_non_quals center" data-stat="xg_diff_per90" data-tip="&lt;strong&gt; ...

# %%
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/206d90db/2018-2019/Barcelona-Stats',
#  '/en/squads/db3b9613/2018-2019/Atletico-Madrid-Stats',
#  '/en/squads/53a2f082/2018-2019/Real-Madrid-Stats',
#  '/en/squads/dcc91a7b/2018-2019/Valencia-Stats',
#  '/en/squads/7848bd64/2018-2019/Getafe-Stats',
#  '/en/squads/ad2be733/2018-2019/Sevilla-Stats',
#  '/en/squads/a8661628/2018-2019/Espanyol-Stats',
#  '/en/squads/2b390eca/2018-2019/Athletic-Club-Stats',
#  '/en/squads/e31d1cd9/2018-2019/Real-Sociedad-Stats',
#  '/en/squads/fc536746/2018-2019/Real-Betis-Stats',
#  '/en/squads/8d6fd021/2018-2019/Alaves-Stats',
#  '/en/squads/bea5c710/2018-2019/Eibar-Stats',
#  '/en/squads/7c6f2c78/2018-2019/Leganes-Stats',
#  '/en/squads/2a8183b3/2018-2019/Villarreal-Stats',
#  '/en/squads/9800b6a1/2018-2019/Levante-Stats',
#  '/en/squads/17859612/2018-2019/Valladolid-Stats',
#  '/en/squads/f25da7fb/2018-2019/Celta-Vigo-Stats',
#  '/en/squads/9024a00a/2018-2019/Girona-Stats',
#  '/en/squads/c6c493e6/2018-2019/Huesca-Stats',
#  '/en/squads/98e8af82/2018-2019/Rayo-Vallecano-Stats']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/206d90db/2018-2019/Barcelona-Stats',
#  'https://fbref.com/en/squads/db3b9613/2018-2019/Atletico-Madrid-Stats',
#  'https://fbref.com/en/squads/53a2f082/2018-2019/Real-Madrid-Stats',
#  'https://fbref.com/en/squads/dcc91a7b/2018-2019/Valencia-Stats',
#  'https://fbref.com/en/squads/7848bd64/2018-2019/Getafe-Stats',
#  'https://fbref.com/en/squads/ad2be733/2018-2019/Sevilla-Stats',
#  'https://fbref.com/en/squads/a8661628/2018-2019/Espanyol-Stats',
#  'https://fbref.com/en/squads/2b390eca/2018-2019/Athletic-Club-Stats',
#  'https://fbref.com/en/squads/e31d1cd9/2018-2019/Real-Sociedad-Stats',
#  'https://fbref.com/en/squads/fc536746/2018-2019/Real-Betis-Stats',
#  'https://fbref.com/en/squads/8d6fd021/2018-2019/Alaves-Stats',
#  'https://fbref.com/en/squads/bea5c710/2018-2019/Eibar-Stats',
#  'https://fbref.com/en/squads/7c6f2c78/2018-2019/Leganes-Stats',
#  'https://fbref.com/en/squads/2a8183b3/2018-2019/Villarreal-Stats',
#  'https://fbref.com/en/squads/9800b6a1/2018-2019/Levante-Stats',
#  'https://fbref.com/en/squads/17859612/2018-2019/Valladolid-Stats',
#  'https://fbref.com/en/squads/f25da7fb/2018-2019/Celta-Vigo-Stats',
#  'https://fbref.com/en/squads/9024a00a/2018-2019/Girona-Stats',
#  'https://fbref.com/en/squads/c6c493e6/2018-2019/Huesca-Stats',
#  'https://fbref.com/en/squads/98e8af82/2018-2019/Rayo-Vallecano-Stats']

# %%
team_url = team_urls[0]
data = requests.get(team_url)
data.text
# Out:
# '    \n      \n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www/base" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202303231" />\n<!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://cmp.quantcast.com\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \n\t\t    \'/choice.js?tag_version=V2\');\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertBefore(element, firstScript);\n\t\n\tfunction makeStub() {\n\t    var TCF_LOCATOR_NAME = \'__tcfapiLocator\';\n\t    var queue = [];\n\t    var win = window;\n\t    var cmpFrame;\n\t    \n\t    function addFrame() {\n\t\tvar doc = win.document;\n\t\tvar otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);\n\t\t\n\t\tif (!otherCMP) {\n\t\t    if (doc.body) {\n\t\t\tvar iframe = doc.createElement(\'iframe\');\n\t\t\t\n\t\t\tiframe.style.cssText = \'display:none\';\n\t\t\tiframe.name = TCF_LOCATOR_NAME;\n\t\t\tdoc.body.appendChild(iframe);\n\t\t    } else {\n\t\t\tsetTimeout(addFrame, 5);\n\t\t    }\n\t\t}\n\t\treturn !otherCMP;\n\t    }\n\t    \n\t    function tcfAPIHandler() {\n\t\tvar gdprApplies;\n\t\tvar args = arguments;\n\t\t\n\t\tif (!args.length) {\n\t\t    return queue;\n\t\t} else if (args[0] === \'setGdprApplies\') {\n\t\t    if (\n\t\t\targs.length > 3 &&\n\t\t\t    args[2] === 2 &&\n\t\t\t    typeof args[3] === \'boolean\'\n\t\t    ) {\n\t\t\tgdprApplies = args[3];\n\t\t\tif (typeof args[2] === \'function\') {\n\t\t\t    args[2](\'set\', true);\n\t\t\t}\n\t\t    }\n\t\t} else if (args[0] === \'ping\') {\n\t\t    var retr = {\n\t\t\tgdprApplies: gdprApplies,\n\t\t\tcmpLoaded: false,\n\t\t\tcmpStatus: \'stub\'\n\t\t    };\n\t\t    \n\t\t    if (typeof args[2] === \'function\') {\n\t\t\targs[2](retr);\n\t\t    }\n\t\t} else {\n\t\t    if(args[0] === \'init\' && typeof args[3] === \'object\') {\n\t\t\targs[3] = Object.assign(args[3], { tag_version: \'V2\' });\n\t\t    }\n\t\t    queue.push(args);\n\t\t}\n\t    }\n\t    \n\t    function postMessageEventHandler(event) {\n\t\tvar msgIsString = typeof event.data === \'string\';\n\t\tvar json = {};\n\t\t\n\t\ttry {\n\t\t    if (msgIsString) {\n\t\t\tjson = JSON.parse(event.data);\n\t\t    } else {\n\t\t\tjson = event.data;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tvar payload = json.__tcfapiCall;\n\t\t\n\t\tif (payload) {\n\t\t    window.__tcfapi(\n\t\t\tpayload.command,\n\t\t\tpayload.version,\n\t\t\tfunction(retValue, success) {\n\t\t\t    var returnMsg = {\n\t\t\t\t__tcfapiReturn: {\n\t\t\t\t    returnValue: retValue,\n\t\t\t\t    success: success,\n\t\t\t\t    callId: payload.callId\n\t\t\t\t}\n\t\t\t    };\n\t\t\t    if (msgIsString) {\n\t\t\t\treturnMsg = JSON.stringify(returnMsg);\n\t\t\t    }\n\t\t\t    if (event && event.source && event.source.postMessage) {\n\t\t\t\tevent.source.postMessage(returnMsg, \'*\');\n\t\t\t    }\n\t\t\t},\n\t\t\tpayload.parameter\n\t\t    );\n\t\t}\n\t    }\n\t    \n\t    while (win) {\n\t\ttry {\n\t\t    if (win.frames[TCF_LOCATOR_NAME]) {\n\t\t\tcmpFrame = win;\n\t\t\tbreak;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tif (win === window.top) {\n\t\t    break;\n\t\t}\n\t\twin = win.parent;\n\t    }\n\t    if (!cmpFrame) {\n\t\taddFrame();\n\t\twin.__tcfapi = tcfAPIHandler;\n\t\twin.addEventListener(\'message\', postMessageEventHandler, false);\n\t    }\n\t};\n\t\n\tmakeStub();\n\t\n\tvar uspStubFunction = function() {\n\t    var arg = arguments;\n\t    if (typ ...

# %%
import pandas as pd

# %%
matches = pd.read_html(data.text, match="Scores & Fixtures")

# %%
matches[0]
# Out:
#           Date   Time                 Comp                Round  Day    Venue  \
# 0   2018-08-12  21:00  Supercopa de España  Supercopa de España  Sun  Neutral
# 1   2018-08-18  22:15              La Liga          Matchweek 1  Sat     Home
# 2   2018-08-25  22:15              La Liga          Matchweek 2  Sat     Away
# 3   2018-09-02  18:30              La Liga          Matchweek 3  Sun     Home
# 4   2018-09-15  16:15              La Liga          Matchweek 4  Sat     Away
# 5   2018-09-18  18:55         Champions Lg          Group stage  Tue     Home
# 6   2018-09-23  20:45              La Liga          Matchweek 5  Sun     Home
# 7   2018-09-26  20:00              La Liga          Matchweek 6  Wed     Away
# 8   2018-09-29  16:15              La Liga          Matchweek 7  Sat     Home
# 9   2018-10-03  20:00         Champions Lg          Group stage  Wed     Away
# 10  2018-10-07  20:45              La Liga          Matchweek 8  Sun     Away
# 11  2018-10-20  20:45              La Liga          Matchweek 9  Sat     Home
# 12  2018-10-24  21:00         Champions Lg          Group stage  Wed     Home
# 13  2018-10-28  16:15              La Liga         Matchweek 10  Sun     Home
# 14  2018-10-31  21:30         Copa del Rey          Round of 32  Wed     Away
#
#    Result  GF  GA            Opponent   xG  xGA  Poss  Attendance  \
# 0       W   2   1             Sevilla  NaN  NaN    69       40000
# 1       W   3   0              Alavés  3.2  0.3    79       52356
# 2       W   1   0          Valladolid  1.0  0.4    64       22651
# 3       W   8   2              Huesca  5.3  1.7    68       72892
# 4       W   2   1       Real Sociedad  1.4  1.4    69       26756
# 5       W   4   0    nl PSV Eindhoven  1.5  0.7    75       73462
# 6       D   2   2              Girona  1.4  1.5    67       76055
# 7       L   1   2             Leganés  0.4  1.1    77       12231
# 8       D   1   1       Athletic Club  3.2  0.9    70       78015
# 9       W   4   2       eng Tottenham  1.4  0.5    61       82137
# 10      D   1   1            Valencia  0.4  1.5    75       46249
# 11      W   4   2             Sevilla  2.5  2.2    53       88712
# 12      W   2   0            it Inter  2.2  1.0    67       86290
# 13      W   5   1         Real Madrid  3.0  2.1    53       93265
# 14      W   1   0             Leonesa  NaN  NaN    68       10873
# 15      W   3   2      Rayo Vallecano  1.9  1.6    69       13785
# 16      D   1   1            it Inter  1.6  1.0    65       70915
# 17      L   3   4               Betis  3.8  2.3    55       83174
# 18      D   1   1     Atlético Madrid  0.6  0.2    69       67204
# 19      W   2   1    nl PSV Eindhoven  2.4  3.0    65       34600
# 20      W   2   0          Villarreal  1.0  1.1    62       73003
# 21      W   4   1             Leonesa  NaN  NaN    53       76398
# 22      W   4   0            Espanyol  2.9  1.1    55       24037
# 23      D   1   1       eng Tottenham  1.3  2.4    49       69961
# 24      W   5   0             Levante  3.7  1.0    57       23736
# 25      W   2   0          Celta Vigo  1.4  0.6    52       78686
# 26      W   2   1              Getafe  1.5  1.2    75       14721
# 27      L   1   2             Levante  NaN  NaN    63       17614
# 28      W   3   0               Eibar  1.1  0.9    58       71039
# 29      W   3   0             Levante  NaN  NaN    69       42838
# 30      W   3   1             Leganés  1.8  0.9    72       50670
# 31      L   0   2             Sevilla  NaN  NaN    60       38403
# 32      W   2   0              Girona  2.2  1.3    64       14021
# 33      W   6   1             Sevilla  NaN  NaN    62       58050
# 34      D   2   2            Valencia  2.0  3.3    68       76789
# 35      D   1   1         Real Madrid  NaN  NaN    57       92008
# 36      D   0   0       Athletic Club  0.7  1.3    67       47557
# 37      W   1   0          Valladolid  3.7  0.4    61       67435
# 38      D   0   0             fr Lyon  2.1  0.3    63       57889
# 39      W   4   2             Sevilla  1.8  1.6    60       40661
# 40      W   3   0         Real Madrid  NaN  NaN    52       80472
# 41      W   1   0         Real Madrid  1.1  0.9    51       78921
# 42      W   3   1      Rayo Vallecano  2.4  0.4    68       74158
# 43      W   5   1             fr Lyon  4.3  0.6    55       92346
# 44      W   4   1               Betis  3.0  1.2    44       54172
# 45      W   2   0            Espanyol  1.3  0.2    69       92795
# 46      D   4   4          Villarreal  2.7  2.2    68       19515
# 47      W   2   0     Atlético Madrid  2.6  0.8    64       92453
# 48      W   1   0  eng Manchester Utd  1.1  0.5    66       74093
# 49      D   0   0              Huesca  1.1  0.2    73        7332
# 50      W   3   0  eng Manchester Utd  1.4  0.4    65       96708
# 39           Lionel Messi     4-3-3  Antonio Matéu Lahoz  Match Report
# 40           Lionel Messi     4-4-2         José Sánchez  Match Report
# 41           Lionel Messi     4-3-3      Alberto Undiano  Match Report
# 42           Lionel Messi     4-3-3         Mario Melero  Match Report
# 43           Lionel Messi     4-3-3     Szymon Marciniak  Match Report
# 44           Lionel Messi     4-4-2    Ricardo de Burgos  Match Report
# 45           Lionel Messi     4-3-3     Carlos del Cerro  Match Report
# 46        Sergio Busquets     4-3-3  Alejandro Hernández  Match Report
# 47           Lionel Messi     4-3-3            Jesús Gil  Match Report
# 48           Lionel Messi     4-3-3      Gianluca Rocchi  Match Report
# 49  Marc-André ter Stegen   3-1-4-2     Guillermo Cuadra  Match Report
# 50           Lionel Messi     4-3-3          Felix Brych  Match Report
# 51           Lionel Messi     4-3-3       Pablo González  Match Report
# 52        Sergio Busquets     4-3-3       Adrián Cordero  Match Report
# 53           Gerard Piqué     4-3-3    Ricardo de Burgos  Match Report
# 54           Lionel Messi     4-4-2        Björn Kuipers  Match Report
# 55       Jasper Cillessen     4-3-3         José Sánchez  Match Report
# 56           Lionel Messi     4-4-2         Cüneyt Çakιr  Match Report
# 57           Lionel Messi     4-3-3        José González  Match Report
# 58           Lionel Messi     4-3-3    José Luis Munuera  Match Report
# 59           Lionel Messi   4-1-4-1      Alberto Undiano  Match Report
#
#                         Notes
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                 Leg 1 of 2
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21  Leg 2 of 2; Barcelona won
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                 Leg 1 of 2
# 28                        NaN
# 29  Leg 2 of 2; Barcelona won
# 30                        NaN
# 31                 Leg 1 of 2
# 32                        NaN
# 33  Leg 2 of 2; Barcelona won
# 34                        NaN
# 35                 Leg 1 of 2
# 36                        NaN
# 37                        NaN
# 38                 Leg 1 of 2
# 39                        NaN
# 40  Leg 2 of 2; Barcelona won
# 41                        NaN
# 42                        NaN
# 43  Leg 2 of 2; Barcelona won
# 44                        NaN
# 45                        NaN
# 46                        NaN
# 47                        NaN
# 48                 Leg 1 of 2
# 49                        NaN
# 50  Leg 2 of 2; Barcelona won
# 51                        NaN
# 52                        NaN
# 53                        NaN
# 54                 Leg 1 of 2
# 55                        NaN
# 56  Leg 2 of 2; Liverpool won
# 57                        NaN
# 58                        NaN
# 59                        NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/206d90db/2018-2019/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2018-2019/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2018-2019/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2018-2019/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Barcelona                                                        \
#            Date   Time                 Comp                Round  Day
# 0    2018-08-12  21:00  Supercopa de España  Supercopa de España  Sun
# 1    2018-08-18  22:15              La Liga          Matchweek 1  Sat
# 2    2018-08-25  22:15              La Liga          Matchweek 2  Sat
# 3    2018-09-02  18:30              La Liga          Matchweek 3  Sun
# 4    2018-09-15  16:15              La Liga          Matchweek 4  Sat
#
#                                         ... Standard               Expected  \
#      Venue Result GF GA       Opponent  ...     Dist   FK PK PKatt       xG
# 0  Neutral      W  2  1        Sevilla  ...      NaN  NaN  0     0      NaN
# 1     Home      W  3  0         Alavés  ...     16.2  2.0  0     0      3.2
# 2     Away      W  1  0     Valladolid  ...     16.9  1.0  0     0      1.0
# 3     Home      W  8  2         Huesca  ...     16.4  2.0  1     1      5.3
# 4     Away      W  2  1  Real Sociedad  ...     12.9  0.0  0     0      1.4
#
#                             Unnamed: 25_level_0
#   npxG npxG/Sh G-xG np:G-xG        Match Report
# 0  NaN     NaN  NaN     NaN        Match Report
# 1  3.2    0.13 -0.2    -0.2        Match Report
# 2  1.0    0.10  0.0     0.0        Match Report
# 3  4.6    0.16  1.7     1.4        Match Report
# 4  1.4    0.13  0.6     0.6        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time                 Comp                Round  Day    Venue  \
# 0  2018-08-12  21:00  Supercopa de España  Supercopa de España  Sun  Neutral
# 1  2018-08-18  22:15              La Liga          Matchweek 1  Sat     Home
# 2  2018-08-25  22:15              La Liga          Matchweek 2  Sat     Away
# 3  2018-09-02  18:30              La Liga          Matchweek 3  Sun     Home
# 4  2018-09-15  16:15              La Liga          Matchweek 4  Sat     Away
#
#   Result  GF  GA       Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  \
# 0      W   2   1        Sevilla  ...   NaN  NaN   0      0  NaN   NaN
# 1      W   3   0         Alavés  ...  16.2  2.0   0      0  3.2   3.2
# 2      W   1   0     Valladolid  ...  16.9  1.0   0      0  1.0   1.0
# 3      W   8   2         Huesca  ...  16.4  2.0   1      1  5.3   4.6
# 4      W   2   1  Real Sociedad  ...  12.9  0.0   0      0  1.4   1.4
#
#    npxG/Sh  G-xG  np:G-xG  Match Report
# 0      NaN   NaN      NaN  Match Report
# 1     0.13  -0.2     -0.2  Match Report
# 2     0.10   0.0      0.0  Match Report
# 3     0.16   1.7      1.4  Match Report
# 4     0.13   0.6      0.6  Match Report
#
# [5 rows x 26 columns]

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data
# Out:
#           Date   Time                 Comp                Round  Day    Venue  \
# 0   2018-08-12  21:00  Supercopa de España  Supercopa de España  Sun  Neutral
# 1   2018-08-18  22:15              La Liga          Matchweek 1  Sat     Home
# 2   2018-08-25  22:15              La Liga          Matchweek 2  Sat     Away
# 3   2018-09-02  18:30              La Liga          Matchweek 3  Sun     Home
# 4   2018-09-15  16:15              La Liga          Matchweek 4  Sat     Away
# 5   2018-09-18  18:55         Champions Lg          Group stage  Tue     Home
# 51  2019-04-20  20:45              La Liga         Matchweek 33  Sat     Home
# 52  2019-04-23  21:30              La Liga         Matchweek 34  Tue     Away
# 53  2019-04-27  20:45              La Liga         Matchweek 35  Sat     Home
# 54  2019-05-01  21:00         Champions Lg          Semi-finals  Wed     Home
# 55  2019-05-04  20:45              La Liga         Matchweek 36  Sat     Away
# 56  2019-05-07  20:00         Champions Lg          Semi-finals  Tue     Away
# 57  2019-05-12  18:30              La Liga         Matchweek 37  Sun     Home
# 58  2019-05-19  16:15              La Liga         Matchweek 38  Sun     Away
# 59  2019-05-25  21:00         Copa del Rey                Final  Sat  Neutral
#
#    Result  GF  GA            Opponent  ...  Formation              Referee  \
# 0       W   2   1             Sevilla  ...      4-3-3     Carlos del Cerro
# 1       W   3   0              Alavés  ...      4-4-2         José Sánchez
# 2       W   1   0          Valladolid  ...      4-3-3    Ricardo de Burgos
# 3       W   8   2              Huesca  ...      4-3-3         Mario Melero
# 4       W   2   1       Real Sociedad  ...      4-3-3     Carlos del Cerro
# 5       W   4   0    nl PSV Eindhoven  ...      4-3-3   Tasos Sidiropoulos
# 6       D   2   2              Girona  ...      4-3-3            Jesús Gil
# 7       L   1   2             Leganés  ...      4-3-3      Alberto Undiano
# 8       D   1   1       Athletic Club  ...      4-3-3       Santiago Jaime
# 9       W   4   2       eng Tottenham  ...      4-3-3       Tobias Stieler
# 10      D   1   1            Valencia  ...      4-3-3        José González
# 11      W   4   2             Sevilla  ...      4-3-3        Juan Martínez
# 12      W   2   0            it Inter  ...      4-3-3       Ovidiu Hațegan
# 13      W   5   1         Real Madrid  ...      4-3-3         José Sánchez
# 14      W   1   0             Leonesa  ...      4-3-3         Mario Melero
# 15      W   3   2      Rayo Vallecano  ...      4-3-3  Alejandro Hernández
# 16      D   1   1            it Inter  ...      4-3-3     Szymon Marciniak
# 17      L   3   4               Betis  ...      4-3-3  Antonio Matéu Lahoz
# 18      D   1   1     Atlético Madrid  ...      4-4-2            Jesús Gil
# 19      W   2   1    nl PSV Eindhoven  ...      4-3-3     Miroslav Zelinka
# 20      W   2   0          Villarreal  ...    4-1-4-1    José Luis Munuera
# 21      W   4   1             Leonesa  ...      4-3-3      Alberto Undiano
# 22      W   4   0            Espanyol  ...      4-3-3     Carlos del Cerro
# 23      D   1   1       eng Tottenham  ...      4-3-3        Milorad Mažić
# 24      W   5   0             Levante  ...      3-5-2        José González
# 25      W   2   0          Celta Vigo  ...      4-3-3       Eduardo Prieto
# 26      W   2   1              Getafe  ...      4-3-3     Guillermo Cuadra
# 27      L   1   2             Levante  ...      3-4-3    Ricardo de Burgos
# 28      W   3   0               Eibar  ...      4-3-3            Jesús Gil
# 29      W   3   0             Levante  ...      4-3-3         José Sánchez
# 30      W   3   1             Leganés  ...      4-3-3    Ricardo de Burgos
# 31      L   0   2             Sevilla  ...      4-3-3     Carlos del Cerro
# 32      W   2   0              Girona  ...      4-3-3       Pablo González
# 33      W   6   1             Sevilla  ...      4-3-3         José Sánchez
# 34      D   2   2            Valencia  ...      4-3-3      Alberto Undiano
# 35      D   1   1         Real Madrid  ...      4-3-3  Antonio Matéu Lahoz
# 36      D   0   0       Athletic Club  ...      4-3-3     Carlos del Cerro
# 37      W   1   0          Valladolid  ...      4-3-3        Juan Martínez
# 38      D   0   0             fr Lyon  ...      4-3-3         Cüneyt Çakιr
# 39      W   4   2             Sevilla  ...      4-3-3  Antonio Matéu Lahoz
# 40      W   3   0         Real Madrid  ...      4-4-2         José Sánchez
# 41      W   1   0         Real Madrid  ...      4-3-3      Alberto Undiano
# 42      W   3   1      Rayo Vallecano  ...      4-3-3         Mario Melero
# 43      W   5   1             fr Lyon  ...      4-3-3     Szymon Marciniak
# 44      W   4   1               Betis  ...      4-4-2    Ricardo de Burgos
# 45      W   2   0            Espanyol  ...      4-3-3     Carlos del Cerro
# 46      D   4   4          Villarreal  ...      4-3-3  Alejandro Hernández
# 47      W   2   0     Atlético Madrid  ...      4-3-3            Jesús Gil
# 48      W   1   0  eng Manchester Utd  ...      4-3-3      Gianluca Rocchi
# 49      D   0   0              Huesca  ...    3-1-4-2     Guillermo Cuadra
# 50      W   3   0  eng Manchester Utd  ...      4-3-3          Felix Brych
# 51      W   2   1       Real Sociedad  ...      4-3-3       Pablo González
# 52      W   2   0              Alavés  ...      4-3-3       Adrián Cordero
# 53      W   1   0             Levante  ...      4-3-3    Ricardo de Burgos
# 54      W   3   0       eng Liverpool  ...      4-4-2        Björn Kuipers
# 55      L   0   2          Celta Vigo  ...      4-3-3         José Sánchez
# 56      L   0   4       eng Liverpool  ...      4-4-2         Cüneyt Çakιr
# 57      W   2   0              Getafe  ...      4-3-3        José González
# 58      D   2   2               Eibar  ...      4-3-3    José Luis Munuera
# 59      L   1   2            Valencia  ...    4-1-4-1      Alberto Undiano
#
#     Match Report                      Notes  Sh SoT  Dist   FK PK  PKatt
# 0   Match Report                        NaN  17   8   NaN  NaN  0      0
# 1   Match Report                        NaN  25   9  16.2  2.0  0      0
# 2   Match Report                        NaN  10   5  16.9  1.0  0      0
# 3   Match Report                        NaN  29  13  16.4  2.0  1      1
# 4   Match Report                        NaN  12   6  12.9  0.0  0      0
# 5   Match Report                        NaN  21   9  20.5  2.0  0      0
# 6   Match Report                        NaN  22  11  20.5  4.0  0      0
# 7   Match Report                        NaN   9   5  21.2  0.0  0      0
# 8   Match Report                        NaN  20   8  17.4  2.0  0      0
# 9   Match Report                        NaN  13   8  18.7  0.0  0      0
# 10  Match Report                        NaN  10   5  24.2  1.0  0      0
# 11  Match Report                        NaN  22   8  20.0  1.0  1      1
# 12  Match Report                        NaN  21  11  17.7  3.0  0      0
# 13  Match Report                        NaN  12   7  17.6  0.0  1      1
# 14  Match Report                 Leg 1 of 2  12   2   NaN  NaN  0      0
# 15  Match Report                        NaN  10   5  15.4  1.0  0      0
# 16  Match Report                        NaN  26   8  19.7  0.0  0      0
# 17  Match Report                        NaN  19   4  15.4  1.0  1      1
# 18  Match Report                        NaN   8   2  22.8  3.0  0      0
# 19  Match Report                        NaN  22   6  16.7  1.0  0      0
# 20  Match Report                        NaN  15   7  21.1  2.0  0      0
# 21  Match Report  Leg 2 of 2; Barcelona won  17   8   NaN  NaN  0      0
# 22  Match Report                        NaN  17   9  13.8  3.0  0      0
# 23  Match Report                        NaN  14   3  19.2  1.0  0      0
# 24  Match Report                        NaN  16   9  18.1  2.0  0      0
# 25  Match Report                        NaN   9   4  19.8  1.0  0      0
# 26  Match Report                        NaN  12   8  17.3  2.0  0      0
# 27  Match Report                 Leg 1 of 2  14   7   NaN  NaN  1      1
# 28  Match Report                        NaN   7   6  11.6  0.0  0      0
# 29  Match Report  Leg 2 of 2; Barcelona won  25  13   NaN  NaN  0      0
# 30  Match Report                        NaN  15   7  16.8  1.0  0      0
# 31  Match Report                 Leg 1 of 2  10   1   NaN  NaN  0      0
# 32  Match Report                        NaN  15   6  18.2  2.0  0      0
# 33  Match Report  Leg 2 of 2; Barcelona won  20  10   NaN  NaN  1      1
# 34  Match Report                        NaN  19   7  21.2  2.0  1      1
# 35  Match Report                 Leg 1 of 2  11   3   NaN  NaN  0      0
# 36  Match Report                        NaN  10   2  22.8  1.0  0      0
# 37  Match Report                        NaN  18   6  19.7  0.0  1      2
# 38  Match Report                 Leg 1 of 2  25   5  18.9  2.0  0      0
# 39  Match Report                        NaN  17   8  18.9  0.0  0      0
# 40  Match Report  Leg 2 of 2; Barcelona won   4   2   NaN  NaN  1      1
# 41  Match Report                        NaN   9   4  19.2  2.0  0      0
# 42  Match Report                        NaN  11   5  18.6  2.0  1      1
# 43  Match Report  Leg 2 of 2; Barcelona won  18   8  15.3  0.0  1      1
# 44  Match Report                        NaN  16   9  16.0  2.0  0      0
# 45  Match Report                        NaN  13   3  17.0  2.0  0      0
# 46  Match Report                        NaN  15   9  19.5  2.0  0      0
# 47  Match Report                        NaN  21  10  19.2  1.0  0      0
# 48  Match Report                 Leg 1 of 2   6   3  13.5  1.0  0      0
# 49  Match Report                        NaN  10   2  15.4  0.0  0      0
# 50  Match Report  Leg 2 of 2; Barcelona won  13   6  19.7  1.0  0      0
# 51  Match Report                        NaN  11   4  15.9  2.0  0      0
# 52  Match Report                        NaN  15   5  17.4  1.0  1      1
# 53  Match Report                        NaN  23  12  17.7  1.0  0      0
# 54  Match Report                 Leg 1 of 2  12   5  12.9  1.0  0      0
# 55  Match Report                        NaN   8   1  20.7  0.0  0      0
# 56  Match Report  Leg 2 of 2; Liverpool won   8   5  18.4  1.0  0      0
# 57  Match Report                        NaN  13   8  14.7  0.0  0      0
# 58  Match Report                        NaN   8   3  19.5  1.0  0      0
# 59  Match Report                        NaN  26   6   NaN  NaN  0      0
#
# [60 rows x 25 columns]

# %%
 years = list(range(2022,2020, -1 ))
 years
# Out:
# [2022, 2021]

# %%
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"

# %%
import time
for year in years:
  data = requests.get(standings_url)
  soup = BeautifulSoup(data.text)
  standings_table = soup.select('table.stats_table')[0]

  links = [l.get("href") for l in standings_table.find_all('a')]
  links = [l for l in links if '/squads/' in l]
  team_urls = [f"https://fbref.com{l}" for l in links]
  
  previous_season = soup.select("a.prev")[0].get("href")
  standings_url = f"https://fbref.com/{previous_season}"



   
  for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats","").replace("-"," ")

    data = requests.get(team_url)
    matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

    soup = BeautifulSoup(data.text)
    links = [l.get("href") for l in soup.find_all('a')]
    links = [l for l in links if l and 'all_comps/shooting/' in l] 
    data = requests.get(f"https://fbref.com{links[0]}")
    shooting = pd.read_html(data.text, match="Shooting")[0]
    shooting.columns = shooting.columns.droplevel()

    try:
      team_data = matches .merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date") 
    except ValueError:
      continue

    team_data = team_data[team_data["Comp"] == "La Liga"]
    team_data["Season"] = year
    team_data["Team"] = team_name 
    all_matches.append(team_data)
    time.sleep(2)

# %%
match_df = pd.concat(all_matches)

# %%
match_df
# Out:
#           Date   Time     Comp         Round  Day Venue Result GF GA  \
# 0   2022-08-13  21:00  La Liga   Matchweek 1  Sat  Home      D  0  0
# 1   2022-08-21  22:00  La Liga   Matchweek 2  Sun  Away      W  4  1
# 2   2022-08-28  19:30  La Liga   Matchweek 3  Sun  Home      W  4  0
# 3   2022-09-03  21:00  La Liga   Matchweek 4  Sat  Away      W  3  0
# 5   2022-09-10  18:30  La Liga   Matchweek 5  Sat  Away      W  4  0
# ..         ...    ...      ...           ...  ...   ...    ... .. ..
# 35  2022-04-30  14:00  La Liga  Matchweek 34  Sat  Home      W  2  1
# 36  2022-05-07  18:30  La Liga  Matchweek 35  Sat  Away      L  0  4
# 37  2022-05-11  19:00  La Liga  Matchweek 36  Wed  Home      W  2  1
# 38  2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      L  1  3
# 39  2022-05-22  20:00  La Liga  Matchweek 38  Sun  Home      L  0  1
#
#           Opponent  ...  Match Report  Notes    Sh  SoT  Dist   FK PK PKatt  \
# 0   Rayo Vallecano  ...  Match Report    NaN  21.0  5.0  17.0  1.0  0     0
# 1    Real Sociedad  ...  Match Report    NaN  15.0  7.0  14.6  0.0  0     0
# 2       Valladolid  ...  Match Report    NaN  24.0  9.0  14.4  1.0  0     0
# 3          Sevilla  ...  Match Report    NaN  18.0  5.0  16.0  2.0  0     0
# 5            Cádiz  ...  Match Report    NaN  16.0  8.0  14.9  0.0  0     0
# ..             ...  ...           ...    ...   ...  ...   ...  ... ..   ...
# 35      Villarreal  ...  Match Report    NaN  11.0  4.0  14.8  0.0  0     0
# 36      Celta Vigo  ...  Match Report    NaN   3.0  1.0  19.5  0.0  0     0
# 37        Espanyol  ...  Match Report    NaN  27.0  9.0  18.0  2.0  0     0
# 38         Levante  ...  Match Report    NaN   6.0  2.0  20.2  1.0  0     0
# 39           Cádiz  ...  Match Report    NaN   9.0  2.0  20.4  2.0  0     0
#
#    Season       Team
# 0    2022  Barcelona
# 1    2022  Barcelona
# 2    2022  Barcelona
# 3    2022  Barcelona
# 5    2022  Barcelona
# ..    ...        ...
# 35   2021     Alaves
# 36   2021     Alaves
# 37   2021     Alaves
# 38   2021     Alaves
# 39   2021     Alaves
#
# [1300 rows x 27 columns]

# %%
match_df.to_csv("matches.csv")

# %%
from google.colab import files
files.download("matches.csv")
